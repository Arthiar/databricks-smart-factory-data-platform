# %% [markdown]
# # Run All Bronze Notebooks
#
# Runs every Bronze Auto Loader notebook in order and finishes with Bronze validation. Keep this notebook inside the same `02_bronze` folder as notebooks `00` to `18`.

# %%
# %run ./00_config

# %%
# %run ./01_autoload_product

# %%
# %run ./02_autoload_product_category

# %%
# %run ./03_autoload_product_subcategory

# %%
# %run ./04_autoload_work_order

# %%
# %run ./05_autoload_work_order_routing

# %%
# %run ./06_autoload_location

# %%
# %run ./07_autoload_scrap_reason

# %%
# %run ./08_autoload_product_inventory

# %%
# %run ./09_autoload_transaction_history

# %%
# %run ./10_autoload_bill_of_materials

# %%
# %run ./11_autoload_vendor

# %%
# %run ./12_autoload_product_vendor

# %%
# %run ./13_autoload_purchase_order_header

# %%
# %run ./14_autoload_purchase_order_detail

# %%
# %run ./15_autoload_customer

# %%
# %run ./16_autoload_sales_order_header

# %%
# %run ./17_autoload_sales_order_detail_fixed

# %%
# %run ./18_validate_bronze

# %%
print("Bronze pipeline and validation completed successfully.")
