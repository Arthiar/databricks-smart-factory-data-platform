# %% [markdown]
# ##Smart Factory Data Platform
# ###Unity Catalog External Locations - Development

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS ext_smart_factory_dev;

CREATE EXTERNAL LOCATION ext_smart_factory_dev
URL 'abfss://smart-factory-dev@stsfactorydev2026.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `sc-smart-factory-dev`)
COMMENT 'Root external location for the Smart Factory development data platform';
